# %%
# !nvidia-smi
# Out:
# Fri Dec 12 20:20:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, zipfile
zip_path = "/content/drive/MyDrive/garbage_project/detector_set.zip"
out_dir = "/content/detector_set"

os.makedirs(out_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall("/content")

# Nếu zip giải nén ra /content/detector_set đúng, thì ok.
# !ls -la /content/detector_set
# !ls -la /content/detector_set/images
# !ls -la /content/detector_set/labels
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 Dec 12 20:30 .
# drwxr-xr-x 1 root root 4096 Dec 12 20:30 ..
# drwxr-xr-x 5 root root 4096 Dec 12 20:30 images
# drwxr-xr-x 5 root root 4096 Dec 12 20:30 labels
# total 28
# drwxr-xr-x 5 root root  4096 Dec 12 20:30 .
# drwxr-xr-x 4 root root  4096 Dec 12 20:30 ..
# drwxr-xr-x 2 root root  4096 Dec 12 20:30 test
# drwxr-xr-x 2 root root 12288 Dec 12 20:30 train
# drwxr-xr-x 2 root root  4096 Dec 12 20:30 val
# total 152
# drwxr-xr-x 5 root root  4096 Dec 12 20:30 .
# drwxr-xr-x 4 root root  4096 Dec 12 20:30 ..
# drwxr-xr-x 2 root root  4096 Dec 12 20:30 test
# -rw-r--r-- 1 root root 28177 Dec 12 20:30 test.cache
# drwxr-xr-x 2 root root 12288 Dec 12 20:30 train
# -rw-r--r-- 1 root root 66377 Dec 12 20:30 train.cache
# drwxr-xr-x 2 root root  4096 Dec 12 20:30 val
# -rw-r--r-- 1 root root 28035 Dec 12 20:30 val.cache

# %%
data_yaml = """
path: /content/detector_set
train: images/train
val: images/val
test: images/test

names:
  0: trash-object
"""
with open("/content/detector_data.yaml", "w") as f:
    f.write(data_yaml)

# !cat /content/detector_data.yaml
# Out:
# path: /content/detector_set
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: trash-object

# %%
# !pip -q install ultralytics

# %%
# !yolo detect train \
  model=yolov8s.pt \
  data=/content/detector_data.yaml \
  imgsz=768 \
  epochs=300 \
  patience=50 \
  batch=16 \
  device=0 \
  cache=True \
  project=/content/runs \
  name=trash_v8s_768_best
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/runs/trash_v8s_768_best/weights/best.pt \
    /content/drive/MyDrive/garbage_project/trash_object_best.pt
# !ls -la /content/drive/MyDrive/garbage_project/
# Out:
# total 689167
# -rw------- 1 root root 683161376 Dec 12 20:19 detector_set.zip
# -rw------- 1 root root  22545066 Dec 12 21:26 trash_object_best.pt
